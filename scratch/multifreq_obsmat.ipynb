# %%
import os
import yaml

from sbi_bmode import script_utils
from sbi_bmode import so_utils, sim_utils

# %%
with open("/u/bing/sbi_bmode/scripts/configs/config_transfer_all_obsmat.yaml", "r") as f:
    config = yaml.safe_load(f)

data_dict, fixed_params_dict, params_dict, observation_dict, transfer_dict = script_utils.parse_config(config)
true_params = script_utils.get_true_params(params_dict)

# %%
# Out:
# {'nside': 128,
#  'lmax': 200,
#  'lmin': 30,
#  'delta_ell': 15,
#  'nsplit': 2,
#  'freq_strings': ['f090', 'f150'],
#  'sensitivity_mode': 'goal',
#  'lknee_mode': 'optimistic',
#  'fsky': 0.1,
#  'cov_scalar_ell': 'camb_lens_nobb.dat',
#  'cov_tensor_ell': 'camb_lens_r1.dat'}
